# %%
# !nvidia-smi
# Out:
# Fri Apr 26 15:27:05 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.22                 Driver Version: 552.22         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   47C    P8              5W /   60W |       0MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch

# %%
torch.__version__
# Out:
# '2.2.2+cu121'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO
 
# Load the model.
model = YOLO('./yolov8m.pt')
 
# Training.
results = model.train(
   data='./data.yaml',
   imgsz=640,
   epochs=30,
   batch=4,
   name='yolov8m_test2_custom')
# Out:
# New https://pypi.org/project/ultralytics/8.2.3 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.42  Python-3.11.7 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 with Max-Q Design, 6144MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('./yolov8m_test2.pt')

# Training.
results = model.predict(
   source='./Sequence 01.mp4',
   show=True,
   save=True,
   show_labels=True,
   show_conf=True,
   line_width=1)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2708) C:\Users\somes\OneDrive\Documents\GitHub\DeepLearningProject\Sequence 01.mp4: 384x640 2 Red-Signals, 121.1ms
# video 1/1 (frame 2/2708) C:\Users\somes\OneDrive\Documents\GitHub\DeepLearningProject\Sequence 01.mp4: 384x640 2 Green-Signals, 2 Red-Signals, 37.5ms
# video 1/1 (frame 3/2708) C:\Users\somes\OneDrive\Documents\GitHub\DeepLearningProject\Sequence 01.mp4: 384x640 2 Green-Signals, 2 Red-Signals, 38.0ms
# ...
