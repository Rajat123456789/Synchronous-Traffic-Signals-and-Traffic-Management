# %%
import  pandas as pd

# %%
df = pd.read_csv('./signalStatus.csv')

# %%
df.head()
# Out:
#            Signal  Red  Yellow  Green  Vehicles_Crossed
# 0    Signal 1 RED  100       5     20                 7
# 1  Signal 2 GREEN    0       5     20                 0
# 2    Signal 3 RED   25       5     20                 0
# 3    Signal 4 RED   75       5     20                 0
# 4             NaN  Red  Yellow  Green  Vehicles Crossed

# %%
i = df[(( df.Red == 'Red') & (df.Yellow == 'Yellow') & (df.Green == 'Green') & (df.Vehicles_Crossed == 'Vehicles Crossed'))].index
df.drop(i, inplace=True)
df.head()
# Out:
#            Signal  Red Yellow Green Vehicles_Crossed
# 0    Signal 1 RED  100      5    20                7
# 1  Signal 2 GREEN    0      5    20                0
# 2    Signal 3 RED   25      5    20                0
# 3    Signal 4 RED   75      5    20                0
# 5    Signal 1 RED   99      5    20                7

# %%
df['Signal_Number'] = df['Signal'].str.extract(r'(Signal \d+)')
df['State'] = df['Signal'].str.extract(r'(RED|GREEN|YELLOW)')

# %%
df
# Out:
#                Signal  Red Yellow Green Vehicles_Crossed Signal_Number  State
# 0        Signal 1 RED  100      5    20                7      Signal 1    RED
# 1      Signal 2 GREEN    0      5    20                0      Signal 2  GREEN
# 2        Signal 3 RED   25      5    20                0      Signal 3    RED
# 3        Signal 4 RED   75      5    20                0      Signal 4    RED
# 5        Signal 1 RED   99      5    20                7      Signal 1    RED
# ...               ...  ...    ...   ...              ...           ...    ...
# 14293  Signal 4 GREEN    0      5     2              473      Signal 4  GREEN
# 14295    Signal 1 RED    6      5    20             1638      Signal 1    RED
# 14296    Signal 2 RED   56      5    20             1751      Signal 2    RED
# 14297    Signal 3 RED   81      5    20              493      Signal 3    RED
# 14298  Signal 4 GREEN    0      5     1              474      Signal 4  GREEN
#
# [11440 rows x 7 columns]

# %%
signals = df['Signal_Number'].unique()
pivoted_dfs = []

for signal in signals:
    signal_df = df[df['Signal_Number'] == signal]
    signal_df = signal_df.drop(columns=['Signal', 'Signal_Number'])
    signal_df = signal_df.rename(columns=lambda x: f"{x}_{signal}")
    pivoted_dfs.append(signal_df.reset_index(drop=True))

# Concatenate the DataFrames side by side
pivoted_df = pd.concat(pivoted_dfs, axis=1)

# %%
pivoted_df.head(30)
# Out:
#    Red_Signal 1 Yellow_Signal 1 Green_Signal 1 Vehicles_Crossed_Signal 1  \
# 0           100               5             20                         7
# 1            99               5             20                         7
# 2            98               5             20                         7
# 3            97               5             20                         7
# 4            96               5             20                         7
# 5            95               5             20                         7
# 6            94               5             20                         7
# 7            93               5             20                         7
# 8            92               5             20                         7
# 9            91               5             20                         7
# 10           90               5             20                         7
# 11           89               5             20                         7
# 12           88               5             20                         7
# 13           87               5             20                         7
# 14           86               5             20                         7
# 15           85               5             20                         7
# 16           84               5             20                         7
# 17           83               5             20                         7
# 18           82               5             20                         7
# 19           81               5             20                         7
# 20           75               5             20                         7
# 21           74               5             20                         7
# 22           73               5             20                         7
# 23           72               5             20                         7
# 24           71               5             20                         7
# 25           70               5             20                         7
# 26           69               5             20                         7
# 27           68               5             20                         7
# 28           67               5             20                         7
# 29           66               5             20                         7
#
#    State_Signal 1 Red_Signal 2 Yellow_Signal 2 Green_Signal 2  \
# 0             RED            0               5             20
# 1             RED            0               5             19
# 2             RED            0               5             18
# 3             RED            0               5             17
# 4             RED            0               5             16
# 5             RED            0               5             15
# 6             RED            0               5             14
# 7             RED            0               5             13
# 8             RED            0               5             12
# 9             RED            0               5             11
# 10            RED            0               5             10
# 11            RED            0               5              9
# 12            RED            0               5              8
# 13            RED            0               5              7
# 14            RED            0               5              6
# 15            RED            0               5              5
# 16            RED            0               5              4
# 17            RED            0               5              3
# 18            RED            0               5              2
# 19            RED            0               5              1
# 20            RED          100               5             20
# 21            RED           99               5             20
# 22            RED           98               5             20
# 23            RED           97               5             20
# 24            RED           96               5             20
# 25            RED           95               5             20
# 26            RED           94               5             20
# 27            RED           93               5             20
# 28            RED           92               5             20
# 29            RED           91               5             20
#
#    Vehicles_Crossed_Signal 2 State_Signal 2 Red_Signal 3 Yellow_Signal 3  \
# 0                          0          GREEN           25               5
# 1                          9          GREEN           24               5
# 2                         11          GREEN           23               5
# 3                         13          GREEN           22               5
# 4                         14          GREEN           21               5
# 5                         15          GREEN           20               5
# 6                         15          GREEN           19               5
# 7                         16          GREEN           18               5
# 8                         17          GREEN           17               5
# 9                         17          GREEN           16               5
# 10                        17          GREEN           15               5
# 11                        17          GREEN           14               5
# 12                        17          GREEN           13               5
# 13                        18          GREEN           12               5
# 14                        18          GREEN           11               5
# 15                        18          GREEN           10               5
# 16                        20          GREEN            9               5
# 17                        20          GREEN            8               5
# 18                        20          GREEN            7               5
# 19                        21          GREEN            6               5
# 20                        22            RED            0               5
# 21                        22            RED            0               5
# 22                        22            RED            0               5
# 23                        22            RED            0               5
# 24                        22            RED            0               5
# 25                        22            RED            0               5
# 26                        22            RED            0               5
# 27                        22            RED            0               5
# 28                        22            RED            0               5
# 29                        22            RED            0               5
#
#    Green_Signal 3 Vehicles_Crossed_Signal 3 State_Signal 3 Red_Signal 4  \
# 0              20                         0            RED           75
# 1              20                         0            RED           74
# 2              20                         0            RED           73
# 3              20                         0            RED           72
# 4              20                         0            RED           71
# 5              20                         0            RED           70
# 6              20                         0            RED           69
# 7              20                         0            RED           68
# 8              20                         0            RED           67
# 9              20                         0            RED           66
# 10             20                         0            RED           65
# 11             20                         0            RED           64
# 12             20                         0            RED           63
# 13             20                         0            RED           62
# 14             20                         0            RED           61
# 15             20                         0            RED           60
# 16             20                         0            RED           59
# 17             20                         0            RED           58
# 18             20                         0            RED           57
# 19             20                         0            RED           56
# 20             20                         0          GREEN           25
# 21             19                         5          GREEN           24
# 22             18                         5          GREEN           23
# 23             17                         5          GREEN           22
# 24             16                         5          GREEN           21
# 25             15                         6          GREEN           20
# 26             14                         6          GREEN           19
# 27             13                         6          GREEN           18
# 28             12                         6          GREEN           17
# 29             11                         6          GREEN           16
#
#    Yellow_Signal 4 Green_Signal 4 Vehicles_Crossed_Signal 4 State_Signal 4
# 0                5             20                         0            RED
# 1                5             20                         0            RED
# 2                5             20                         0            RED
# 3                5             20                         0            RED
# 4                5             20                         0            RED
# 5                5             20                         0            RED
# 6                5             20                         0            RED
# 7                5             20                         0            RED
# 8                5             20                         0            RED
# 9                5             20                         0            RED
# 10               5             20                         0            RED
# 11               5             20                         0            RED
# 12               5             20                         0            RED
# 13               5             20                         0            RED
# 14               5             20                         0            RED
# 15               5             20                         0            RED
# 16               5             20                         0            RED
# 17               5             20                         0            RED
# 18               5             20                         0            RED
# 19               5             20                         0            RED
# 20               5             20                         0            RED
# 21               5             20                         0            RED
# 22               5             20                         0            RED
# 23               5             20                         0            RED
# 24               5             20                         0            RED
# 25               5             20                         0            RED
# 26               5             20                         0            RED
# 27               5             20                         0            RED
# 28               5             20                         0            RED
# 29               5             20                         0            RED

# %%
pivoted_df = pivoted_df.loc[:, ~pivoted_df.columns.str.contains('Yellow')]

pivoted_df.head(30)
# Out:
#    Red_Signal 1 Green_Signal 1 Vehicles_Crossed_Signal 1 State_Signal 1  \
# 0           100             20                         7            RED
# 1            99             20                         7            RED
# 2            98             20                         7            RED
# 3            97             20                         7            RED
# 4            96             20                         7            RED
# 5            95             20                         7            RED
# 6            94             20                         7            RED
# 7            93             20                         7            RED
# 8            92             20                         7            RED
# 9            91             20                         7            RED
# 10           90             20                         7            RED
# 11           89             20                         7            RED
# 12           88             20                         7            RED
# 13           87             20                         7            RED
# 14           86             20                         7            RED
# 15           85             20                         7            RED
# 16           84             20                         7            RED
# 17           83             20                         7            RED
# 18           82             20                         7            RED
# 19           81             20                         7            RED
# 20           75             20                         7            RED
# 21           74             20                         7            RED
# 22           73             20                         7            RED
# 23           72             20                         7            RED
# 24           71             20                         7            RED
# 25           70             20                         7            RED
# 26           69             20                         7            RED
# 27           68             20                         7            RED
# 28           67             20                         7            RED
# 29           66             20                         7            RED
#
#    Red_Signal 2 Green_Signal 2 Vehicles_Crossed_Signal 2 State_Signal 2  \
# 0             0             20                         0          GREEN
# 1             0             19                         9          GREEN
# 2             0             18                        11          GREEN
# 3             0             17                        13          GREEN
# 4             0             16                        14          GREEN
# 5             0             15                        15          GREEN
# 6             0             14                        15          GREEN
# 7             0             13                        16          GREEN
# 8             0             12                        17          GREEN
# 9             0             11                        17          GREEN
# 10            0             10                        17          GREEN
# 11            0              9                        17          GREEN
# 12            0              8                        17          GREEN
# 13            0              7                        18          GREEN
# 14            0              6                        18          GREEN
# 15            0              5                        18          GREEN
# 16            0              4                        20          GREEN
# 17            0              3                        20          GREEN
# 18            0              2                        20          GREEN
# 19            0              1                        21          GREEN
# 20          100             20                        22            RED
# 21           99             20                        22            RED
# 22           98             20                        22            RED
# 23           97             20                        22            RED
# 24           96             20                        22            RED
# 25           95             20                        22            RED
# 26           94             20                        22            RED
# 27           93             20                        22            RED
# 28           92             20                        22            RED
# 29           91             20                        22            RED
#
#    Red_Signal 3 Green_Signal 3 Vehicles_Crossed_Signal 3 State_Signal 3  \
# 0            25             20                         0            RED
# 1            24             20                         0            RED
# 2            23             20                         0            RED
# 3            22             20                         0            RED
# 4            21             20                         0            RED
# 5            20             20                         0            RED
# 6            19             20                         0            RED
# 7            18             20                         0            RED
# 8            17             20                         0            RED
# 9            16             20                         0            RED
# 10           15             20                         0            RED
# 11           14             20                         0            RED
# 12           13             20                         0            RED
# 13           12             20                         0            RED
# 14           11             20                         0            RED
# 15           10             20                         0            RED
# 16            9             20                         0            RED
# 17            8             20                         0            RED
# 18            7             20                         0            RED
# 19            6             20                         0            RED
# 20            0             20                         0          GREEN
# 21            0             19                         5          GREEN
# 22            0             18                         5          GREEN
# 23            0             17                         5          GREEN
# 24            0             16                         5          GREEN
# 25            0             15                         6          GREEN
# 26            0             14                         6          GREEN
# 27            0             13                         6          GREEN
# 28            0             12                         6          GREEN
# 29            0             11                         6          GREEN
#
#    Red_Signal 4 Green_Signal 4 Vehicles_Crossed_Signal 4 State_Signal 4
# 0            75             20                         0            RED
# 1            74             20                         0            RED
# 2            73             20                         0            RED
# 3            72             20                         0            RED
# 4            71             20                         0            RED
# 5            70             20                         0            RED
# 6            69             20                         0            RED
# 7            68             20                         0            RED
# 8            67             20                         0            RED
# 9            66             20                         0            RED
# 10           65             20                         0            RED
# 11           64             20                         0            RED
# 12           63             20                         0            RED
# 13           62             20                         0            RED
# 14           61             20                         0            RED
# 15           60             20                         0            RED
# 16           59             20                         0            RED
# 17           58             20                         0            RED
# 18           57             20                         0            RED
# 19           56             20                         0            RED
# 20           25             20                         0            RED
# 21           24             20                         0            RED
# 22           23             20                         0            RED
# 23           22             20                         0            RED
# 24           21             20                         0            RED
# 25           20             20                         0            RED
# 26           19             20                         0            RED
# 27           18             20                         0            RED
# 28           17             20                         0            RED
# 29           16             20                         0            RED

# %%
def reorder_columns(df):
    columns = df.columns.tolist()
    reordered_columns = []

    # Extract unique signal identifiers
    signals = sorted(set(col.split('_')[-1] for col in columns if 'Signal' in col))

    # Desired order for each signal
    order = ['State', 'Red', 'Green', 'Vehicles_Crossed']

    # Reorder columns for each signal
    for signal in signals:
        for col_prefix in order:
            reordered_columns.append(f'{col_prefix}_{signal}')

    return df[reordered_columns]

# Reorder columns
pivoted_df = reorder_columns(pivoted_df)

pivoted_df.head(30)
# Out:
#    State_Signal 1 Red_Signal 1 Green_Signal 1 Vehicles_Crossed_Signal 1  \
# 0             RED          100             20                         7
# 1             RED           99             20                         7
# 2             RED           98             20                         7
# 3             RED           97             20                         7
# 4             RED           96             20                         7
# 5             RED           95             20                         7
# 6             RED           94             20                         7
# 7             RED           93             20                         7
# 8             RED           92             20                         7
# 9             RED           91             20                         7
# 10            RED           90             20                         7
# 11            RED           89             20                         7
# 12            RED           88             20                         7
# 13            RED           87             20                         7
# 14            RED           86             20                         7
# 15            RED           85             20                         7
# 16            RED           84             20                         7
# 17            RED           83             20                         7
# 18            RED           82             20                         7
# 19            RED           81             20                         7
# 20            RED           75             20                         7
# 21            RED           74             20                         7
# 22            RED           73             20                         7
# 23            RED           72             20                         7
# 24            RED           71             20                         7
# 25            RED           70             20                         7
# 26            RED           69             20                         7
# 27            RED           68             20                         7
# 28            RED           67             20                         7
# 29            RED           66             20                         7
#
#    State_Signal 2 Red_Signal 2 Green_Signal 2 Vehicles_Crossed_Signal 2  \
# 0           GREEN            0             20                         0
# 1           GREEN            0             19                         9
# 2           GREEN            0             18                        11
# 3           GREEN            0             17                        13
# 4           GREEN            0             16                        14
# 5           GREEN            0             15                        15
# 6           GREEN            0             14                        15
# 7           GREEN            0             13                        16
# 8           GREEN            0             12                        17
# 9           GREEN            0             11                        17
# 10          GREEN            0             10                        17
# 11          GREEN            0              9                        17
# 12          GREEN            0              8                        17
# 13          GREEN            0              7                        18
# 14          GREEN            0              6                        18
# 15          GREEN            0              5                        18
# 16          GREEN            0              4                        20
# 17          GREEN            0              3                        20
# 18          GREEN            0              2                        20
# 19          GREEN            0              1                        21
# 20            RED          100             20                        22
# 21            RED           99             20                        22
# 22            RED           98             20                        22
# 23            RED           97             20                        22
# 24            RED           96             20                        22
# 25            RED           95             20                        22
# 26            RED           94             20                        22
# 27            RED           93             20                        22
# 28            RED           92             20                        22
# 29            RED           91             20                        22
#
#    State_Signal 3 Red_Signal 3 Green_Signal 3 Vehicles_Crossed_Signal 3  \
# 0             RED           25             20                         0
# 1             RED           24             20                         0
# 2             RED           23             20                         0
# 3             RED           22             20                         0
# 4             RED           21             20                         0
# 5             RED           20             20                         0
# 6             RED           19             20                         0
# 7             RED           18             20                         0
# 8             RED           17             20                         0
# 9             RED           16             20                         0
# 10            RED           15             20                         0
# 11            RED           14             20                         0
# 12            RED           13             20                         0
# 13            RED           12             20                         0
# 14            RED           11             20                         0
# 15            RED           10             20                         0
# 16            RED            9             20                         0
# 17            RED            8             20                         0
# 18            RED            7             20                         0
# 19            RED            6             20                         0
# 20          GREEN            0             20                         0
# 21          GREEN            0             19                         5
# 22          GREEN            0             18                         5
# 23          GREEN            0             17                         5
# 24          GREEN            0             16                         5
# 25          GREEN            0             15                         6
# 26          GREEN            0             14                         6
# 27          GREEN            0             13                         6
# 28          GREEN            0             12                         6
# 29          GREEN            0             11                         6
#
#    State_Signal 4 Red_Signal 4 Green_Signal 4 Vehicles_Crossed_Signal 4
# 0             RED           75             20                         0
# 1             RED           74             20                         0
# 2             RED           73             20                         0
# 3             RED           72             20                         0
# 4             RED           71             20                         0
# 5             RED           70             20                         0
# 6             RED           69             20                         0
# 7             RED           68             20                         0
# 8             RED           67             20                         0
# 9             RED           66             20                         0
# 10            RED           65             20                         0
# 11            RED           64             20                         0
# 12            RED           63             20                         0
# 13            RED           62             20                         0
# 14            RED           61             20                         0
# 15            RED           60             20                         0
# 16            RED           59             20                         0
# 17            RED           58             20                         0
# 18            RED           57             20                         0
# 19            RED           56             20                         0
# 20            RED           25             20                         0
# 21            RED           24             20                         0
# 22            RED           23             20                         0
# 23            RED           22             20                         0
# 24            RED           21             20                         0
# 25            RED           20             20                         0
# 26            RED           19             20                         0
# 27            RED           18             20                         0
# 28            RED           17             20                         0
# 29            RED           16             20                         0

# %%
pivoted_df.head(50)
# Out:
#    State_Signal 1 Red_Signal 1 Green_Signal 1 Vehicles_Crossed_Signal 1  \
# 0             RED          100             20                         7
# 1             RED           99             20                         7
# 2             RED           98             20                         7
# 3             RED           97             20                         7
# 4             RED           96             20                         7
# 5             RED           95             20                         7
# 6             RED           94             20                         7
# 7             RED           93             20                         7
# 8             RED           92             20                         7
# 9             RED           91             20                         7
# 10            RED           90             20                         7
# 11            RED           89             20                         7
# 12            RED           88             20                         7
# 13            RED           87             20                         7
# 14            RED           86             20                         7
# 15            RED           85             20                         7
# 16            RED           84             20                         7
# 17            RED           83             20                         7
# 18            RED           82             20                         7
# 19            RED           81             20                         7
# 20            RED           75             20                         7
# 21            RED           74             20                         7
# 22            RED           73             20                         7
# 23            RED           72             20                         7
# 24            RED           71             20                         7
# 25            RED           70             20                         7
# 26            RED           69             20                         7
# 27            RED           68             20                         7
# 28            RED           67             20                         7
# 29            RED           66             20                         7
# 30            RED           65             20                         7
# 31            RED           64             20                         7
# 32            RED           63             20                         7
# 33            RED           62             20                         7
# 34            RED           61             20                         7
# 35            RED           60             20                         7
# 36            RED           59             20                         7
# 37            RED           58             20                         7
# 38            RED           57             20                         7
# 39            RED           56             20                         7
# 40            RED           25             20                         7
# 41            RED           24             20                         7
# 42            RED           23             20                         7
# 43            RED           22             20                         7
# 44            RED           21             20                         7
# 45            RED           20             20                         7
# 46            RED           19             20                         7
# 47            RED           18             20                         7
# 48            RED           17             20                         7
# 49            RED           16             20                         7
#
#    State_Signal 2 Red_Signal 2 Green_Signal 2 Vehicles_Crossed_Signal 2  \
# 0           GREEN            0             20                         0
# 1           GREEN            0             19                         9
# 2           GREEN            0             18                        11
# 3           GREEN            0             17                        13
# 4           GREEN            0             16                        14
# 5           GREEN            0             15                        15
# 6           GREEN            0             14                        15
# 7           GREEN            0             13                        16
# 8           GREEN            0             12                        17
# 9           GREEN            0             11                        17
# 10          GREEN            0             10                        17
# 11          GREEN            0              9                        17
# 12          GREEN            0              8                        17
# 13          GREEN            0              7                        18
# 14          GREEN            0              6                        18
# 15          GREEN            0              5                        18
# 16          GREEN            0              4                        20
# 17          GREEN            0              3                        20
# 18          GREEN            0              2                        20
# 19          GREEN            0              1                        21
# 20            RED          100             20                        22
# 21            RED           99             20                        22
# 22            RED           98             20                        22
# 23            RED           97             20                        22
# 24            RED           96             20                        22
# 25            RED           95             20                        22
# 26            RED           94             20                        22
# 27            RED           93             20                        22
# 28            RED           92             20                        22
# 29            RED           91             20                        22
# 30            RED           90             20                        22
# 31            RED           89             20                        22
# 32            RED           88             20                        22
# 33            RED           87             20                        22
# 34            RED           86             20                        22
# 35            RED           85             20                        22
# 36            RED           84             20                        22
# 37            RED           83             20                        22
# 38            RED           82             20                        22
# 39            RED           81             20                        22
# 40            RED           75             20                        22
# 41            RED           74             20                        22
# 42            RED           73             20                        22
# 43            RED           72             20                        22
# 44            RED           71             20                        22
# 45            RED           70             20                        22
# 46            RED           69             20                        22
# 47            RED           68             20                        22
# 48            RED           67             20                        22
# 49            RED           66             20                        22
#
#    State_Signal 3 Red_Signal 3 Green_Signal 3 Vehicles_Crossed_Signal 3  \
# 0             RED           25             20                         0
# 1             RED           24             20                         0
# 2             RED           23             20                         0
# 3             RED           22             20                         0
# 4             RED           21             20                         0
# 5             RED           20             20                         0
# 6             RED           19             20                         0
# 7             RED           18             20                         0
# 8             RED           17             20                         0
# 9             RED           16             20                         0
# 10            RED           15             20                         0
# 11            RED           14             20                         0
# 12            RED           13             20                         0
# 13            RED           12             20                         0
# 14            RED           11             20                         0
# 15            RED           10             20                         0
# 16            RED            9             20                         0
# 17            RED            8             20                         0
# 18            RED            7             20                         0
# 19            RED            6             20                         0
# 20          GREEN            0             20                         0
# 21          GREEN            0             19                         5
# 22          GREEN            0             18                         5
# 23          GREEN            0             17                         5
# 24          GREEN            0             16                         5
# 25          GREEN            0             15                         6
# 26          GREEN            0             14                         6
# 27          GREEN            0             13                         6
# 28          GREEN            0             12                         6
# 29          GREEN            0             11                         6
# 30          GREEN            0             10                         6
# 31          GREEN            0              9                         6
# 32          GREEN            0              8                         7
# 33          GREEN            0              7                         7
# 34          GREEN            0              6                         8
# 35          GREEN            0              5                         8
# 36          GREEN            0              4                         8
# 37          GREEN            0              3                         8
# 38          GREEN            0              2                         8
# 39          GREEN            0              1                         8
# 40            RED          100             20                         8
# 41            RED           99             20                         8
# 42            RED           98             20                         8
# 43            RED           97             20                         8
# 44            RED           96             20                         8
# 45            RED           95             20                         8
# 46            RED           94             20                         8
# 47            RED           93             20                         8
# 48            RED           92             20                         8
# 49            RED           91             20                         8
#
#    State_Signal 4 Red_Signal 4 Green_Signal 4 Vehicles_Crossed_Signal 4
# 0             RED           75             20                         0
# 1             RED           74             20                         0
# 2             RED           73             20                         0
# 3             RED           72             20                         0
# 4             RED           71             20                         0
# 5             RED           70             20                         0
# 6             RED           69             20                         0
# 7             RED           68             20                         0
# 8             RED           67             20                         0
# 9             RED           66             20                         0
# 10            RED           65             20                         0
# 11            RED           64             20                         0
# 12            RED           63             20                         0
# 13            RED           62             20                         0
# 14            RED           61             20                         0
# 15            RED           60             20                         0
# 16            RED           59             20                         0
# 17            RED           58             20                         0
# 18            RED           57             20                         0
# 19            RED           56             20                         0
# 20            RED           25             20                         0
# 21            RED           24             20                         0
# 22            RED           23             20                         0
# 23            RED           22             20                         0
# 24            RED           21             20                         0
# 25            RED           20             20                         0
# 26            RED           19             20                         0
# 27            RED           18             20                         0
# 28            RED           17             20                         0
# 29            RED           16             20                         0
# 30            RED           15             20                         0
# 31            RED           14             20                         0
# 32            RED           13             20                         0
# 33            RED           12             20                         0
# 34            RED           11             20                         0
# 35            RED           10             20                         0
# 36            RED            9             20                         0
# 37            RED            8             20                         0
# 38            RED            7             20                         0
# 39            RED            6             20                         0
# 40          GREEN            0             20                         0
# 41          GREEN            0             19                         7
# 42          GREEN            0             18                        12
# 43          GREEN            0             17                        13
# 44          GREEN            0             16                        13
# 45          GREEN            0             15                        13
# 46          GREEN            0             14                        13
# 47          GREEN            0             13                        13
# 48          GREEN            0             12                        14
# 49          GREEN            0             11                        14

# %%
pivoted_df.to_csv('./test.csv')

# %%
import matplotlib.pyplot as plt

def plot_traffic_flow(data):
    plt.figure(figsize=(14, 7))
    
    for i in range(1, 5):
        plt.plot(data.index, data[f'Vehicles_Crossed_Signal {i}'], label=f'Signal {i}')
    
    plt.title('Traffic Flow Over Time')
    plt.xlabel('Time')
    plt.ylabel('Number of Vehicles')
    plt.legend()
    plt.show()

# Assuming `data` is a pandas DataFrame with a datetime index
plot_traffic_flow(pivoted_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vehicles_Crossed_Signal_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 16
#      13     plt.show()
#      15 # Assuming `data` is a pandas DataFrame with a datetime index
# ---> 16 plot_traffic_flow(pivoted_df)
#
# Cell In[31], line 7, in plot_traffic_flow(data)
#       4 plt.figure(figsize=(14, 7))
#       6 for i in range(1, 5):
# ----> 7     plt.plot(data.index, data[f'Vehicles_Crossed_Signal_{i}'], label=f'Signal {i}')
#       9 plt.title('Traffic Flow Over Time')
#      10 plt.xlabel('Time')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Vehicles_Crossed_Signal_1'
